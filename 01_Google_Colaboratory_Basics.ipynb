# %% [markdown]
# <a href="https://colab.research.google.com/github/Seiko-5/Google-Colaboratory-/blob/main/01_Google_Colaboratory_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01. System Specifications

# %% [markdown]
# CPU Information

# %%
# !cat /proc/cpuinfo

# %% [markdown]
# RAM Information

# %%
# !cat /proc/meminfo

# %% [markdown]
# # 02. Installing Libraries

# %%
# !pip install pandas

# %% [markdown]
# # 03. Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # 04. Import Data

# %%
df = pd.read_csv('/content/tp3_boston_data.csv')
